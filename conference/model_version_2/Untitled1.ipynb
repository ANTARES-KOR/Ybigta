# %%
import pandas as pd
import re

# %%
track = pd.read_json("./data/track/track_dataset.json", encoding = 'utf-8', orient='records')

# %%
track
# Out:
#            artist_name                              track_name  \
# 0         Harry Styles                               As It Was
# 1            Kate Bush  Running Up That Hill (A Deal With God)
# 2            Bad Bunny                         Me Porto Bonito
# 3                 Joji                           Glimpse of Us
# 4            Bad Bunny                           Ojitos Lindos
# ..                 ...                                     ...
# 580              SHAUN                           Way Back Home
# 581            Weeekly                            After School
# 582              Punch                             BOM BOM BOM
# 583              ASTRO                          After Midnight
# 584  Girls' Generation                                 Holiday
#
#                                             album_name  \
# 0                                        Harry's House
# 1                                       Hounds Of Love
# ...

# %%
track.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 585 entries, 0 to 584
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   artist_name        585 non-null    object
#  1   track_name         585 non-null    object
#  2   album_name         585 non-null    object
#  3   artist_genre       585 non-null    object
#  4   artist_popularity  585 non-null    int64
#  5   track_popularity   585 non-null    int64
#  6   artist_followers   585 non-null    int64
#  7   danceability       585 non-null    float64
#  8   energy             585 non-null    float64
#  9   key                585 non-null    int64
#  10  loudness           585 non-null    float64
#  11  speechiness        585 non-null    float64
#  12  acousticness       585 non-null    float64
#  13  instrumentalness   585 non-null    float64
#  14  liveness           585 non-null    float64
#  15  valence            585 non-null    float64
# ...

# %%
def cleanText(text_data):
    text = re.sub('[-=+#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]','', text_data)
    return text

# %%
a = pd.DataFrame(track.artist_genre)
b = str(a.artist_genre[0])
type(b)
# Out:
# str

# %%
cleanText(b)
# Out:
# 'pop'
